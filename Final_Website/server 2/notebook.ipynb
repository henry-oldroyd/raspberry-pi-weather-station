# %%
from server import db

# %% [markdown]
# The purpose of this file is to create all tables defined in the server.py
#
# following what tutorial does at this point: https://youtu.be/y_Wc2qwVKbg?t=739

# %%
db.create_all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\henry\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# c:\Users\henry\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# c:\Users\henry\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# c:\Users\henry\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
# ...
