# %%
# local import
import server_22 as server
import random
import typing
import sqlalchemy as sqla
# Out:
# server_22.py - INFO - this logger named server_22.py created
# 2022-06-02 14:21:23,911 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-02 14:21:23,912 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("readings_uncalibrated")
# 2022-06-02 14:21:23,913 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-02 14:21:23,914 INFO sqlalchemy.engine.Engine COMMIT

# %%
new_readings_json = {
    'pressure': random.uniform(0, 30),
    'temperature': random.uniform(0, 30),
    'humidity': random.uniform(0, 30),
    'wind_speed': random.uniform(0, 30),
    'wind_direction': random.uniform(0, 30),
    'precipitation': random.uniform(0, 30)
}

new_reading: server.Reading_Uncalibrated = server.reading_uncalibrated_schema.load(new_readings_json, session=server.session)

new_reading
# Out:
# <Reading_Uncalibrated(timestamp=2022-06-02 14:21:23.963355)>

# %%
server.reading_uncalibrated_schema.dump(new_reading)
# Out:
# {'primary_key': None,
#  'wind_speed': 16.982684824761968,
#  'humidity': 17.90198271577722,
#  'pressure': 9.579561781832297,
#  'timestamp': '2022-06-02 14:21:23',
#  'wind_direction': 26.090110942928998,
#  'temperature': 21.314669557168337,
#  'precipitation': 3.545809889089532}

# %%
def gen_new_readings_json():
    for _ in range(30):
        yield {
            'pressure': random.uniform(0, 30),
            'temperature': random.uniform(0, 30),
            'humidity': random.uniform(0, 30),
            'wind_speed': random.uniform(0, 30),
            'wind_direction': random.uniform(0, 30),
            'precipitation': random.uniform(0, 30)
        }

# %%
new_readings_json = list(gen_new_readings_json())
sorted(new_readings_json, key=lambda e: e['pressure'])
# Out:
# [{'pressure': 0.8830002245144031,
#   'temperature': 15.966552221310263,
#   'humidity': 25.363572720662198,
#   'wind_speed': 14.395397300586383,
#   'wind_direction': 12.127122291759756,
#   'precipitation': 25.35417044930093},
#  {'pressure': 1.322356866533535,
#   'temperature': 25.410881642525386,
#   'humidity': 7.431294466259414,
#   'wind_speed': 25.607809637674734,
#   'wind_direction': 18.633632133956223,
#   'precipitation': 2.7839282929708986},
#  {'pressure': 1.3859583805799536,
#   'temperature': 19.834987765854553,
#   'humidity': 24.251617375151913,
#   'wind_speed': 24.99058101931693,
#   'wind_direction': 14.020655738057496,
#   'precipitation': 0.9411082878571508},
#  {'pressure': 3.424557485907014,
#   'temperature': 2.4206791165342945,
#   'humidity': 5.0059066229247495,
#   'wind_speed': 10.331027410205204,
#   'wind_direction': 17.464965696567717,
#   'precipitation': 5.265228366077578},
#  {'pressure': 3.4489484900365284,
#   'temperature': 16.911894366351063,
#   'humidity': 23.008022365439484,
#   'wind_speed': 18.918727191759462,
#   'wind_direction': 0.869541106709667,
#   'precipitation': 16.93689939733214},
#  {'pressure': 3.715214664150346,
#   'temperature': 0.14966227665488718,
#   'humidity': 18.230074190649635,
#   'wind_speed': 28.68941400936299,
#   'wind_direction': 11.444796401763035,
#   'precipitation': 5.321832473448072},
#  {'pressure': 4.451592312383157,
#   'temperature': 16.247695730838533,
#   'humidity': 2.6634572982665903,
#   'wind_speed': 7.978108726007954,
#   'wind_direction': 0.8981161187767184,
#   'precipitation': 26.205977296221274},
#  {'pressure': 5.613674729187413,
#   'temperature': 17.54106515182257,
#   'humidity': 25.089232225814712,
#   'wind_speed': 23.354832637638502,
#   'wind_direction': 8.278461602826093,
#   'precipitation': 18.312589758166034},
#  {'pressure': 5.71098062765362,
#   'temperature': 6.297100612740815,
#   'humidity': 7.453239857934309,
#   'wind_speed': 15.159242017057394,
#   'wind_direction': 26.476660484284974,
#   'precipitation': 21.37632388792062},
#  {'pressure': 6.1144086866354765,
#   'temperature': 16.622778287335652,
#   'humidity': 18.764116764249447,
#   'wind_speed': 16.488479409887564,
#   'wind_direction': 19.544089558322312,
#   'precipitation': 28.31820850299108},
#  {'pressure': 7.157026398854217,
#   'temperature': 21.473378905389055,
#   'humidity': 12.963219845950743,
#   'wind_speed': 14.08666195581159,
#   'wind_direction': 11.853876400675178,
#   'precipitation': 26.400785915278345},
#  {'pressure': 7.90143983138768,
#   'temperature': 29.380135094706255,
#   'humidity': 26.6307695249055,
#   'wind_speed': 8.845447248225947,
#   'wind_direction': 9.747970097526151,
#   'precipitation': 19.05846148128628},
#  {'pressure': 8.1584212824749,
#   'temperature': 28.951877520142034,
#   'humidity': 1.7815542518886651,
#   'wind_speed': 12.266743398624104,
#   'wind_direction': 27.3005233719603,
#   'precipitation': 8.67346430953679},
#  {'pressure': 8.266889640257432,
#   'temperature': 0.022750521347504327,
#   'humidity': 10.834678629095125,
#   'wind_speed': 2.055036910952418,
#   'wind_direction': 11.730832177699753,
#   'precipitation': 14.85300992519885},
#  {'pressure': 8.286200271023091,
#   'temperature': 27.8449229296005,
#   'humidity': 14.013514942628413,
#   'wind_speed': 25.89694114793668,
#   'wind_direction': 9.70860455912675,
#   'precipitation': 5.911900082480201},
#  {'pressure': 9.702617467271285,
#   'temperature': 7.923328021706757,
#   'humidity': 0.1298692610380392,
#   'wind_speed': 14.303198796295526,
#   'wind_direction': 16.694991121531075,
#   'precipitation': 4.138671598512939},
#  {'pressure': 11.191322402431611,
#   'temperature': 15.675227133014559,
#   'humidity': 4.233236867503258,
#   'wind_speed': 26.578547626947305,
#   'wind_direction': 4.1379212140800625,
#   'precipitation': 2.2003213838639457},
#  {'pressure': 14.339839105500706,
#   'temperature': 22.387355350977117,
#   'humidity': 24.459657570504458,
#   'wind_speed': 1.8985237754837592,
#   'wind_direction': 14.358964376214699,
#   'precipitation': 17.194843310983096},
#  {'pressure': 14.563572094240083,
#   'temperature': 2.674310226362194,
#   'humidity': 19.73000890769485,
#   'wind_speed': 5.180475104442371,
#   'wind_direction': 7.709105607600801,
#   'precipitation': 29.21670873967035},
#  {'pressure': 14.680547308864051,
#   'temperature': 26.82967892472847,
#   'humidity': 22.72177299193787,
#   'wind_speed': 15.165896046983846,
#   'wind_direction': 8.85862332830355,
#   'precipitation': 19.76144595093841},
#  {'pressure': 14.920047510960831,
#   'temperature': 13.934319949672803,
#   'humidity': 21.216708198945913,
#   'wind_speed': 29.332036257269998,
#   'wind_direction': 7.318244660021202,
#   'precipitation': 26.56900896176852},
#  {'pressure': 16.70103872126127,
#   'temperature': 4.066010088822613,
#   'humidity': 28.593014100772574,
#   'wind_speed': 20.966420688966917,
#   'wind_direction': 25.63918781231772,
#   'precipitation': 29.733519194179177},
#  {'pressure': 17.773521618513218,
#   'temperature': 26.7269105607801,
#   'humidity': 8.547488004022973,
#   'wind_speed': 10.96156968338568,
#   'wind_direction': 10.579585054292712,
#   'precipitation': 15.45644044371696},
#  {'pressure': 21.52912912005338,
#   'temperature': 14.312769416594683,
#   'humidity': 14.11329497232045,
#   'wind_speed': 21.37946218732377,
#   'wind_direction': 23.646999166096837,
#   'precipitation': 27.627723822803127},
#  {'pressure': 21.814503671144195,
#   'temperature': 8.816749356808053,
#   'humidity': 1.3940333114020997,
#   'wind_speed': 7.239868920424878,
#   'wind_direction': 5.518837397403348,
#   'precipitation': 14.90151925959405},
#  {'pressure': 23.350456010507582,
#   'temperature': 16.636705763415,
#   'humidity': 29.853842042472234,
#   'wind_speed': 15.428790903540186,
#   'wind_direction': 29.43640212423146,
#   'precipitation': 2.1340005383685448},
#  {'pressure': 23.49993424853604,
#   'temperature': 0.8446856548052561,
#   'humidity': 25.773540338692918,
#   'wind_speed': 14.485600945466919,
#   'wind_direction': 29.955001660712774,
#   'precipitation': 13.24542993242368},
#  {'pressure': 23.805244032871133,
#   'temperature': 1.5648965201781895,
#   'humidity': 19.974008356376714,
#   'wind_speed': 20.23249278675624,
#   'wind_direction': 20.904823889599644,
#   'precipitation': 24.018017562268113},
#  {'pressure': 28.845748852418836,
#   'temperature': 16.85871769805461,
#   'humidity': 16.37726434252422,
#   'wind_speed': 1.4662261496255913,
#   'wind_direction': 29.30843126282076,
#   'precipitation': 6.373313840611866},
#  {'pressure': 29.797121255043393,
#   'temperature': 8.417161954242738,
#   'humidity': 21.805071868864832,
#   'wind_speed': 21.203625112819832,
#   'wind_direction': 18.0965892709854,
#   'precipitation': 29.97337821466542}]

# %%
new_readings: typing.Iterable = server.reading_uncalibrated_schema_many.load(new_readings_json, session=server.session)

# %%
server.session.bulk_save_objects(new_readings)
server.session.commit()
# Out:
# 2022-06-02 14:21:24,362 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-02 14:21:24,367 INFO sqlalchemy.engine.Engine INSERT INTO readings_uncalibrated (timestamp, pressure, temperature, humidity, wind_speed, wind_direction, precipitation) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2022-06-02 14:21:24,368 INFO sqlalchemy.engine.Engine [generated in 0.00183s] (('2022-06-02 14:21:24.236790', 0.8830002245144031, 15.966552221310263, 25.363572720662198, 14.395397300586383, 12.127122291759756, 25.35417044930093), ('2022-06-02 14:21:24.236790', 28.845748852418836, 16.85871769805461, 16.37726434252422, 1.4662261496255913, 29.30843126282076, 6.373313840611866), ('2022-06-02 14:21:24.237291', 17.773521618513218, 26.7269105607801, 8.547488004022973, 10.96156968338568, 10.579585054292712, 15.45644044371696), ('2022-06-02 14:21:24.237291', 8.286200271023091, 27.8449229296005, 14.013514942628413, 25.89694114793668, 9.70860455912675, 5.911900082480201), ('2022-06-02 14:21:24.237291', 7.90143983138768, 29.380135094706255, 26.6307695249055, 8.845447248225947, 9.747970097526151, 19.05846148128628), ('2022-06-02 14:21:24.237790', 8.1584212824749, 28.951877520142034, 1.7815542518886651, 12.266743398624104, 27.3005233719603, 8.67346430953679), ('2022-06-02 14:21:24.237790', 7.157026398854217, 21.473378905389055, 12.963219845950743, 14.08666195581159, 11.853876400675178, 26.400785915278345), ('2022-06-02 14:21:24.237790', 14.680547308864051, 26.82967892472847, 22.72177299193787, 15.165896046983846, 8.85862332830355, 19.76144595093841)  ... displaying 10 of 30 total bound parameter sets ...  ('2022-06-02 14:21:24.243673', 14.920047510960831, 13.934319949672803, 21.216708198945913, 29.332036257269998, 7.318244660021202, 26.56900896176852), ('2022-06-02 14:21:24.243673', 8.266889640257432, 0.022750521347504327, 10.834678629095125, 2.055036910952418, 11.730832177699753, 14.85300992519885))
# 2022-06-02 14:21:24,372 INFO sqlalchemy.engine.Engine COMMIT

# %%
query = sqla.select(server.Reading_Uncalibrated)
all_readings = list(server.session.scalars(query))
all_readings
# Out:
# 2022-06-02 14:21:24,505 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-02 14:21:24,510 INFO sqlalchemy.engine.Engine SELECT readings_uncalibrated.primary_key, readings_uncalibrated.timestamp, readings_uncalibrated.pressure, readings_uncalibrated.temperature, readings_uncalibrated.humidity, readings_uncalibrated.wind_speed, readings_uncalibrated.wind_direction, readings_uncalibrated.precipitation
# FROM readings_uncalibrated
# 2022-06-02 14:21:24,512 INFO sqlalchemy.engine.Engine [generated in 0.00117s] ()
# [<Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.236790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.236790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237291)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237291)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237291)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.237790)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.239236)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.239236)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.239860)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.240370)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.241211)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.241211)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.241711)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.241747)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.241747)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.242272)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.242272)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.242774)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.243077)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.243162)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.243162)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.243673)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 14:21:24.243673)>]

# %%
serialised_readings: dict = server.reading_uncalibrated_schema_many.dump(all_readings)

sorted(serialised_readings, key=lambda e: e['pressure'])
# Out:
# [{'primary_key': 1,
#   'wind_speed': 14.395397300586383,
#   'humidity': 25.363572720662198,
#   'pressure': 0.8830002245144031,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 12.127122291759756,
#   'temperature': 15.966552221310263,
#   'precipitation': 25.35417044930093},
#  {'primary_key': 18,
#   'wind_speed': 25.607809637674734,
#   'humidity': 7.431294466259414,
#   'pressure': 1.322356866533535,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 18.633632133956223,
#   'temperature': 25.410881642525386,
#   'precipitation': 2.7839282929708986},
#  {'primary_key': 17,
#   'wind_speed': 24.99058101931693,
#   'humidity': 24.251617375151913,
#   'pressure': 1.3859583805799536,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 14.020655738057496,
#   'temperature': 19.834987765854553,
#   'precipitation': 0.9411082878571508},
#  {'primary_key': 27,
#   'wind_speed': 10.331027410205204,
#   'humidity': 5.0059066229247495,
#   'pressure': 3.424557485907014,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 17.464965696567717,
#   'temperature': 2.4206791165342945,
#   'precipitation': 5.265228366077578},
#  {'primary_key': 14,
#   'wind_speed': 18.918727191759462,
#   'humidity': 23.008022365439484,
#   'pressure': 3.4489484900365284,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 0.869541106709667,
#   'temperature': 16.911894366351063,
#   'precipitation': 16.93689939733214},
#  {'primary_key': 11,
#   'wind_speed': 28.68941400936299,
#   'humidity': 18.230074190649635,
#   'pressure': 3.715214664150346,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 11.444796401763035,
#   'temperature': 0.14966227665488718,
#   'precipitation': 5.321832473448072},
#  {'primary_key': 12,
#   'wind_speed': 7.978108726007954,
#   'humidity': 2.6634572982665903,
#   'pressure': 4.451592312383157,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 0.8981161187767184,
#   'temperature': 16.247695730838533,
#   'precipitation': 26.205977296221274},
#  {'primary_key': 19,
#   'wind_speed': 23.354832637638502,
#   'humidity': 25.089232225814712,
#   'pressure': 5.613674729187413,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 8.278461602826093,
#   'temperature': 17.54106515182257,
#   'precipitation': 18.312589758166034},
#  {'primary_key': 28,
#   'wind_speed': 15.159242017057394,
#   'humidity': 7.453239857934309,
#   'pressure': 5.71098062765362,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 26.476660484284974,
#   'temperature': 6.297100612740815,
#   'precipitation': 21.37632388792062},
#  {'primary_key': 21,
#   'wind_speed': 16.488479409887564,
#   'humidity': 18.764116764249447,
#   'pressure': 6.1144086866354765,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 19.544089558322312,
#   'temperature': 16.622778287335652,
#   'precipitation': 28.31820850299108},
#  {'primary_key': 7,
#   'wind_speed': 14.08666195581159,
#   'humidity': 12.963219845950743,
#   'pressure': 7.157026398854217,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 11.853876400675178,
#   'temperature': 21.473378905389055,
#   'precipitation': 26.400785915278345},
#  {'primary_key': 5,
#   'wind_speed': 8.845447248225947,
#   'humidity': 26.6307695249055,
#   'pressure': 7.90143983138768,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 9.747970097526151,
#   'temperature': 29.380135094706255,
#   'precipitation': 19.05846148128628},
#  {'primary_key': 6,
#   'wind_speed': 12.266743398624104,
#   'humidity': 1.7815542518886651,
#   'pressure': 8.1584212824749,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 27.3005233719603,
#   'temperature': 28.951877520142034,
#   'precipitation': 8.67346430953679},
#  {'primary_key': 30,
#   'wind_speed': 2.055036910952418,
#   'humidity': 10.834678629095125,
#   'pressure': 8.266889640257432,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 11.730832177699753,
#   'temperature': 0.022750521347504327,
#   'precipitation': 14.85300992519885},
#  {'primary_key': 4,
#   'wind_speed': 25.89694114793668,
#   'humidity': 14.013514942628413,
#   'pressure': 8.286200271023091,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 9.70860455912675,
#   'temperature': 27.8449229296005,
#   'precipitation': 5.911900082480201},
#  {'primary_key': 22,
#   'wind_speed': 14.303198796295526,
#   'humidity': 0.1298692610380392,
#   'pressure': 9.702617467271285,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 16.694991121531075,
#   'temperature': 7.923328021706757,
#   'precipitation': 4.138671598512939},
#  {'primary_key': 10,
#   'wind_speed': 26.578547626947305,
#   'humidity': 4.233236867503258,
#   'pressure': 11.191322402431611,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 4.1379212140800625,
#   'temperature': 15.675227133014559,
#   'precipitation': 2.2003213838639457},
#  {'primary_key': 26,
#   'wind_speed': 1.8985237754837592,
#   'humidity': 24.459657570504458,
#   'pressure': 14.339839105500706,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 14.358964376214699,
#   'temperature': 22.387355350977117,
#   'precipitation': 17.194843310983096},
#  {'primary_key': 23,
#   'wind_speed': 5.180475104442371,
#   'humidity': 19.73000890769485,
#   'pressure': 14.563572094240083,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 7.709105607600801,
#   'temperature': 2.674310226362194,
#   'precipitation': 29.21670873967035},
#  {'primary_key': 8,
#   'wind_speed': 15.165896046983846,
#   'humidity': 22.72177299193787,
#   'pressure': 14.680547308864051,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 8.85862332830355,
#   'temperature': 26.82967892472847,
#   'precipitation': 19.76144595093841},
#  {'primary_key': 29,
#   'wind_speed': 29.332036257269998,
#   'humidity': 21.216708198945913,
#   'pressure': 14.920047510960831,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 7.318244660021202,
#   'temperature': 13.934319949672803,
#   'precipitation': 26.56900896176852},
#  {'primary_key': 16,
#   'wind_speed': 20.966420688966917,
#   'humidity': 28.593014100772574,
#   'pressure': 16.70103872126127,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 25.63918781231772,
#   'temperature': 4.066010088822613,
#   'precipitation': 29.733519194179177},
#  {'primary_key': 3,
#   'wind_speed': 10.96156968338568,
#   'humidity': 8.547488004022973,
#   'pressure': 17.773521618513218,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 10.579585054292712,
#   'temperature': 26.7269105607801,
#   'precipitation': 15.45644044371696},
#  {'primary_key': 15,
#   'wind_speed': 21.37946218732377,
#   'humidity': 14.11329497232045,
#   'pressure': 21.52912912005338,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 23.646999166096837,
#   'temperature': 14.312769416594683,
#   'precipitation': 27.627723822803127},
#  {'primary_key': 9,
#   'wind_speed': 7.239868920424878,
#   'humidity': 1.3940333114020997,
#   'pressure': 21.814503671144195,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 5.518837397403348,
#   'temperature': 8.816749356808053,
#   'precipitation': 14.90151925959405},
#  {'primary_key': 24,
#   'wind_speed': 15.428790903540186,
#   'humidity': 29.853842042472234,
#   'pressure': 23.350456010507582,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 29.43640212423146,
#   'temperature': 16.636705763415,
#   'precipitation': 2.1340005383685448},
#  {'primary_key': 13,
#   'wind_speed': 14.485600945466919,
#   'humidity': 25.773540338692918,
#   'pressure': 23.49993424853604,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 29.955001660712774,
#   'temperature': 0.8446856548052561,
#   'precipitation': 13.24542993242368},
#  {'primary_key': 25,
#   'wind_speed': 20.23249278675624,
#   'humidity': 19.974008356376714,
#   'pressure': 23.805244032871133,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 20.904823889599644,
#   'temperature': 1.5648965201781895,
#   'precipitation': 24.018017562268113},
#  {'primary_key': 2,
#   'wind_speed': 1.4662261496255913,
#   'humidity': 16.37726434252422,
#   'pressure': 28.845748852418836,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 29.30843126282076,
#   'temperature': 16.85871769805461,
#   'precipitation': 6.373313840611866},
#  {'primary_key': 20,
#   'wind_speed': 21.203625112819832,
#   'humidity': 21.805071868864832,
#   'pressure': 29.797121255043393,
#   'timestamp': '2022-06-02 14:21:24',
#   'wind_direction': 18.0965892709854,
#   'temperature': 8.417161954242738,
#   'precipitation': 29.97337821466542}]
