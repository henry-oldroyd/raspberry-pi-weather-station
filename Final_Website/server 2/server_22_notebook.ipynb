# %%
# local import
import server_22 as server
import random
import typing
import sqlalchemy as sqla
# Out:
# server_22.py - INFO - this logger named server_22.py created

# %%
new_readings_json = {
    'pressure': random.uniform(0, 30),
    'temperature': random.uniform(0, 30),
    'humidity': random.uniform(0, 30),
    'wind_speed': random.uniform(0, 30),
    'wind_direction': random.uniform(0, 30),
    'precipitation': random.uniform(0, 30)
}

new_reading: server.Reading_Uncalibrated = server.reading_uncalibrated_schema.load(new_readings_json, session=server.session)

new_reading
# Out:
# <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.453854)>

# %%
server.reading_uncalibrated_schema.dump(new_reading)
# Out:
# {'wind_direction': 21.081947617170112,
#  'temperature': 9.970218400488012,
#  'precipitation': 19.87012012821421,
#  'humidity': 1.4524235723429701,
#  'wind_speed': 24.931815806424595,
#  'primary_key': None,
#  'pressure': 0.03079713220820124}

# %%
def gen_new_readings_json():
    for _ in range(30):
        yield {
            'pressure': random.uniform(0, 30),
            'temperature': random.uniform(0, 30),
            'humidity': random.uniform(0, 30),
            'wind_speed': random.uniform(0, 30),
            'wind_direction': random.uniform(0, 30),
            'precipitation': random.uniform(0, 30)
        }

# %%
new_readings_json = list(gen_new_readings_json())
sorted(new_readings_json, key=lambda e: e['pressure'])
# Out:
# [{'pressure': 4.173244097626066,
#   'temperature': 14.725926277247874,
#   'humidity': 15.79047028872078,
#   'wind_speed': 22.223155993292142,
#   'wind_direction': 12.220317149804995,
#   'precipitation': 8.790900447726507},
#  {'pressure': 4.194140788338029,
#   'temperature': 27.011024691224357,
#   'humidity': 20.343076258891088,
#   'wind_speed': 18.294651230061273,
#   'wind_direction': 20.102687493006297,
#   'precipitation': 21.77928079967322},
#  {'pressure': 4.955379623208723,
#   'temperature': 12.264253970168461,
#   'humidity': 11.540592460419543,
#   'wind_speed': 1.3106296431221398,
#   'wind_direction': 21.907943041104406,
#   'precipitation': 12.950296762462546},
#  {'pressure': 5.457381178978446,
#   'temperature': 6.978563506072641,
#   'humidity': 8.464230644293915,
#   'wind_speed': 7.418141553023958,
#   'wind_direction': 14.432027095071872,
#   'precipitation': 16.210379184708895},
#  {'pressure': 5.486564338175009,
#   'temperature': 10.751429997620372,
#   'humidity': 15.9169897269453,
#   'wind_speed': 12.133151931758553,
#   'wind_direction': 1.1581894726455155,
#   'precipitation': 4.991286349713814},
#  {'pressure': 6.216564930941918,
#   'temperature': 22.647348200518376,
#   'humidity': 2.1916221556898288,
#   'wind_speed': 1.1901550424269292,
#   'wind_direction': 26.64692291420058,
#   'precipitation': 4.555946399417006},
#  {'pressure': 7.586891246485036,
#   'temperature': 4.580448511295739,
#   'humidity': 3.317081032260789,
#   'wind_speed': 17.367383685529916,
#   'wind_direction': 3.590997258872173,
#   'precipitation': 0.7013892068538485},
#  {'pressure': 7.764766545002427,
#   'temperature': 5.829565766333607,
#   'humidity': 28.443396534077223,
#   'wind_speed': 26.68775260783804,
#   'wind_direction': 15.740237943997194,
#   'precipitation': 1.7174979440822213},
#  {'pressure': 7.795437748528583,
#   'temperature': 11.942762184750407,
#   'humidity': 28.219551609479833,
#   'wind_speed': 25.48065383272278,
#   'wind_direction': 16.468724519241476,
#   'precipitation': 21.800344468219695},
#  {'pressure': 12.140050814375705,
#   'temperature': 27.4859691643356,
#   'humidity': 22.834936493376382,
#   'wind_speed': 28.979132908395144,
#   'wind_direction': 14.590250039177768,
#   'precipitation': 2.7401805016486422},
#  {'pressure': 13.101262871472576,
#   'temperature': 21.228708043557464,
#   'humidity': 28.020993975552198,
#   'wind_speed': 0.4165658740429945,
#   'wind_direction': 18.00908558476165,
#   'precipitation': 9.141233918971874},
#  {'pressure': 13.817057054684044,
#   'temperature': 0.14875251927162325,
#   'humidity': 3.090253160799387,
#   'wind_speed': 21.256801460237284,
#   'wind_direction': 28.343199748589292,
#   'precipitation': 4.015733143873048},
#  {'pressure': 13.928598860107854,
#   'temperature': 11.399380099716419,
#   'humidity': 29.11963682798787,
#   'wind_speed': 18.959030032086112,
#   'wind_direction': 23.318761324009532,
#   'precipitation': 0.022642931446948955},
#  {'pressure': 15.174255906296452,
#   'temperature': 22.971474770929554,
#   'humidity': 16.24149593446464,
#   'wind_speed': 23.09255487471487,
#   'wind_direction': 14.38474174479384,
#   'precipitation': 21.111732352727945},
#  {'pressure': 16.83345660890504,
#   'temperature': 29.206655749876816,
#   'humidity': 23.677689354071656,
#   'wind_speed': 7.742140555080291,
#   'wind_direction': 5.586151417596619,
#   'precipitation': 5.679733298999903},
#  {'pressure': 17.083137383040253,
#   'temperature': 9.869063774604067,
#   'humidity': 10.213503366293867,
#   'wind_speed': 2.6270929245238595,
#   'wind_direction': 15.675934676002704,
#   'precipitation': 3.6543209703843713},
#  {'pressure': 17.436745279158767,
#   'temperature': 16.02606772587574,
#   'humidity': 0.19033035055602943,
#   'wind_speed': 21.91961644354865,
#   'wind_direction': 1.155728677756157,
#   'precipitation': 5.69043614339779},
#  {'pressure': 18.59485817022343,
#   'temperature': 0.45410224831388235,
#   'humidity': 17.299351421246726,
#   'wind_speed': 3.8841500209832747,
#   'wind_direction': 5.107768060120485,
#   'precipitation': 7.72075921703829},
#  {'pressure': 21.368072048031664,
#   'temperature': 22.600414988272654,
#   'humidity': 8.109372583861843,
#   'wind_speed': 13.972018209738724,
#   'wind_direction': 8.579346650747887,
#   'precipitation': 10.825797508572897},
#  {'pressure': 21.610713401969516,
#   'temperature': 20.087450536954837,
#   'humidity': 1.5347289410333387,
#   'wind_speed': 3.387058236629712,
#   'wind_direction': 1.6515120388886373,
#   'precipitation': 25.971503541715283},
#  {'pressure': 21.862401023982233,
#   'temperature': 21.997301858048452,
#   'humidity': 1.3964675220006462,
#   'wind_speed': 15.486760872290873,
#   'wind_direction': 5.998286883758811,
#   'precipitation': 11.01232030301991},
#  {'pressure': 22.911073974452467,
#   'temperature': 12.983103083030208,
#   'humidity': 14.09403353887228,
#   'wind_speed': 6.797993365020131,
#   'wind_direction': 28.383469236727986,
#   'precipitation': 19.95658318421664},
#  {'pressure': 23.0349730630642,
#   'temperature': 29.084377169012996,
#   'humidity': 25.27171522399929,
#   'wind_speed': 3.602136749477082,
#   'wind_direction': 12.963927149385174,
#   'precipitation': 16.14577035329293},
#  {'pressure': 23.49544210513557,
#   'temperature': 8.604440009451306,
#   'humidity': 2.6217376244451183,
#   'wind_speed': 1.0103155344545767,
#   'wind_direction': 14.589796043688505,
#   'precipitation': 7.614030472407198},
#  {'pressure': 24.259424555432577,
#   'temperature': 20.75227153164466,
#   'humidity': 26.665178153495024,
#   'wind_speed': 1.640340141843044,
#   'wind_direction': 13.078288940073652,
#   'precipitation': 9.04922926508415},
#  {'pressure': 24.731113646645724,
#   'temperature': 23.10060420566301,
#   'humidity': 29.299614718956395,
#   'wind_speed': 16.107063701795767,
#   'wind_direction': 25.247281200160412,
#   'precipitation': 26.04486612634515},
#  {'pressure': 25.550672095170068,
#   'temperature': 26.59210298300083,
#   'humidity': 22.30564717950782,
#   'wind_speed': 6.932106628028922,
#   'wind_direction': 28.208482109898792,
#   'precipitation': 20.85305366989846},
#  {'pressure': 26.56568791821422,
#   'temperature': 0.7577129269646765,
#   'humidity': 8.003433142806287,
#   'wind_speed': 1.7144978909789566,
#   'wind_direction': 4.630687788940544,
#   'precipitation': 5.513007178515771},
#  {'pressure': 27.08589976941871,
#   'temperature': 24.03147984516633,
#   'humidity': 8.22350384418115,
#   'wind_speed': 12.672654471249745,
#   'wind_direction': 25.02877559757658,
#   'precipitation': 13.884009796267367},
#  {'pressure': 27.73016218864073,
#   'temperature': 17.845896936642518,
#   'humidity': 9.35063792331219,
#   'wind_speed': 25.610258263463113,
#   'wind_direction': 7.513891477748823,
#   'precipitation': 27.332968400245957}]

# %%
new_readings: typing.Iterable = server.reading_uncalibrated_schema_many.load(new_readings_json, session=server.session)

# %%
server.session.bulk_save_objects(new_readings)
server.session.commit()

# %%
query = sqla.select(server.Reading_Uncalibrated)
all_readings = list(server.session.scalars(query))
all_readings
# Out:
# [<Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.748199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.748199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.749199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.750198)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>,
#  <Reading_Uncalibrated(timestamp=2022-06-02 13:36:20.751199)>]

# %%
serialised_readings: dict = server.reading_uncalibrated_schema_many.dump(all_readings)

sorted(serialised_readings, key=lambda e: e['pressure'])
# Out:
# [{'wind_direction': 12.220317149804995,
#   'temperature': 14.725926277247874,
#   'precipitation': 8.790900447726507,
#   'humidity': 15.79047028872078,
#   'wind_speed': 22.223155993292142,
#   'primary_key': 17,
#   'pressure': 4.173244097626066},
#  {'wind_direction': 20.102687493006297,
#   'temperature': 27.011024691224357,
#   'precipitation': 21.77928079967322,
#   'humidity': 20.343076258891088,
#   'wind_speed': 18.294651230061273,
#   'primary_key': 29,
#   'pressure': 4.194140788338029},
#  {'wind_direction': 21.907943041104406,
#   'temperature': 12.264253970168461,
#   'precipitation': 12.950296762462546,
#   'humidity': 11.540592460419543,
#   'wind_speed': 1.3106296431221398,
#   'primary_key': 5,
#   'pressure': 4.955379623208723},
#  {'wind_direction': 14.432027095071872,
#   'temperature': 6.978563506072641,
#   'precipitation': 16.210379184708895,
#   'humidity': 8.464230644293915,
#   'wind_speed': 7.418141553023958,
#   'primary_key': 10,
#   'pressure': 5.457381178978446},
#  {'wind_direction': 1.1581894726455155,
#   'temperature': 10.751429997620372,
#   'precipitation': 4.991286349713814,
#   'humidity': 15.9169897269453,
#   'wind_speed': 12.133151931758553,
#   'primary_key': 19,
#   'pressure': 5.486564338175009},
#  {'wind_direction': 26.64692291420058,
#   'temperature': 22.647348200518376,
#   'precipitation': 4.555946399417006,
#   'humidity': 2.1916221556898288,
#   'wind_speed': 1.1901550424269292,
#   'primary_key': 9,
#   'pressure': 6.216564930941918},
#  {'wind_direction': 3.590997258872173,
#   'temperature': 4.580448511295739,
#   'precipitation': 0.7013892068538485,
#   'humidity': 3.317081032260789,
#   'wind_speed': 17.367383685529916,
#   'primary_key': 3,
#   'pressure': 7.586891246485036},
#  {'wind_direction': 15.740237943997194,
#   'temperature': 5.829565766333607,
#   'precipitation': 1.7174979440822213,
#   'humidity': 28.443396534077223,
#   'wind_speed': 26.68775260783804,
#   'primary_key': 7,
#   'pressure': 7.764766545002427},
#  {'wind_direction': 16.468724519241476,
#   'temperature': 11.942762184750407,
#   'precipitation': 21.800344468219695,
#   'humidity': 28.219551609479833,
#   'wind_speed': 25.48065383272278,
#   'primary_key': 24,
#   'pressure': 7.795437748528583},
#  {'wind_direction': 14.590250039177768,
#   'temperature': 27.4859691643356,
#   'precipitation': 2.7401805016486422,
#   'humidity': 22.834936493376382,
#   'wind_speed': 28.979132908395144,
#   'primary_key': 16,
#   'pressure': 12.140050814375705},
#  {'wind_direction': 18.00908558476165,
#   'temperature': 21.228708043557464,
#   'precipitation': 9.141233918971874,
#   'humidity': 28.020993975552198,
#   'wind_speed': 0.4165658740429945,
#   'primary_key': 25,
#   'pressure': 13.101262871472576},
#  {'wind_direction': 28.343199748589292,
#   'temperature': 0.14875251927162325,
#   'precipitation': 4.015733143873048,
#   'humidity': 3.090253160799387,
#   'wind_speed': 21.256801460237284,
#   'primary_key': 30,
#   'pressure': 13.817057054684044},
#  {'wind_direction': 23.318761324009532,
#   'temperature': 11.399380099716419,
#   'precipitation': 0.022642931446948955,
#   'humidity': 29.11963682798787,
#   'wind_speed': 18.959030032086112,
#   'primary_key': 20,
#   'pressure': 13.928598860107854},
#  {'wind_direction': 14.38474174479384,
#   'temperature': 22.971474770929554,
#   'precipitation': 21.111732352727945,
#   'humidity': 16.24149593446464,
#   'wind_speed': 23.09255487471487,
#   'primary_key': 23,
#   'pressure': 15.174255906296452},
#  {'wind_direction': 5.586151417596619,
#   'temperature': 29.206655749876816,
#   'precipitation': 5.679733298999903,
#   'humidity': 23.677689354071656,
#   'wind_speed': 7.742140555080291,
#   'primary_key': 1,
#   'pressure': 16.83345660890504},
#  {'wind_direction': 15.675934676002704,
#   'temperature': 9.869063774604067,
#   'precipitation': 3.6543209703843713,
#   'humidity': 10.213503366293867,
#   'wind_speed': 2.6270929245238595,
#   'primary_key': 4,
#   'pressure': 17.083137383040253},
#  {'wind_direction': 1.155728677756157,
#   'temperature': 16.02606772587574,
#   'precipitation': 5.69043614339779,
#   'humidity': 0.19033035055602943,
#   'wind_speed': 21.91961644354865,
#   'primary_key': 6,
#   'pressure': 17.436745279158767},
#  {'wind_direction': 5.107768060120485,
#   'temperature': 0.45410224831388235,
#   'precipitation': 7.72075921703829,
#   'humidity': 17.299351421246726,
#   'wind_speed': 3.8841500209832747,
#   'primary_key': 22,
#   'pressure': 18.59485817022343},
#  {'wind_direction': 8.579346650747887,
#   'temperature': 22.600414988272654,
#   'precipitation': 10.825797508572897,
#   'humidity': 8.109372583861843,
#   'wind_speed': 13.972018209738724,
#   'primary_key': 12,
#   'pressure': 21.368072048031664},
#  {'wind_direction': 1.6515120388886373,
#   'temperature': 20.087450536954837,
#   'precipitation': 25.971503541715283,
#   'humidity': 1.5347289410333387,
#   'wind_speed': 3.387058236629712,
#   'primary_key': 13,
#   'pressure': 21.610713401969516},
#  {'wind_direction': 5.998286883758811,
#   'temperature': 21.997301858048452,
#   'precipitation': 11.01232030301991,
#   'humidity': 1.3964675220006462,
#   'wind_speed': 15.486760872290873,
#   'primary_key': 8,
#   'pressure': 21.862401023982233},
#  {'wind_direction': 28.383469236727986,
#   'temperature': 12.983103083030208,
#   'precipitation': 19.95658318421664,
#   'humidity': 14.09403353887228,
#   'wind_speed': 6.797993365020131,
#   'primary_key': 15,
#   'pressure': 22.911073974452467},
#  {'wind_direction': 12.963927149385174,
#   'temperature': 29.084377169012996,
#   'precipitation': 16.14577035329293,
#   'humidity': 25.27171522399929,
#   'wind_speed': 3.602136749477082,
#   'primary_key': 14,
#   'pressure': 23.0349730630642},
#  {'wind_direction': 14.589796043688505,
#   'temperature': 8.604440009451306,
#   'precipitation': 7.614030472407198,
#   'humidity': 2.6217376244451183,
#   'wind_speed': 1.0103155344545767,
#   'primary_key': 11,
#   'pressure': 23.49544210513557},
#  {'wind_direction': 13.078288940073652,
#   'temperature': 20.75227153164466,
#   'precipitation': 9.04922926508415,
#   'humidity': 26.665178153495024,
#   'wind_speed': 1.640340141843044,
#   'primary_key': 18,
#   'pressure': 24.259424555432577},
#  {'wind_direction': 25.247281200160412,
#   'temperature': 23.10060420566301,
#   'precipitation': 26.04486612634515,
#   'humidity': 29.299614718956395,
#   'wind_speed': 16.107063701795767,
#   'primary_key': 21,
#   'pressure': 24.731113646645724},
#  {'wind_direction': 28.208482109898792,
#   'temperature': 26.59210298300083,
#   'precipitation': 20.85305366989846,
#   'humidity': 22.30564717950782,
#   'wind_speed': 6.932106628028922,
#   'primary_key': 27,
#   'pressure': 25.550672095170068},
#  {'wind_direction': 4.630687788940544,
#   'temperature': 0.7577129269646765,
#   'precipitation': 5.513007178515771,
#   'humidity': 8.003433142806287,
#   'wind_speed': 1.7144978909789566,
#   'primary_key': 2,
#   'pressure': 26.56568791821422},
#  {'wind_direction': 25.02877559757658,
#   'temperature': 24.03147984516633,
#   'precipitation': 13.884009796267367,
#   'humidity': 8.22350384418115,
#   'wind_speed': 12.672654471249745,
#   'primary_key': 28,
#   'pressure': 27.08589976941871},
#  {'wind_direction': 7.513891477748823,
#   'temperature': 17.845896936642518,
#   'precipitation': 27.332968400245957,
#   'humidity': 9.35063792331219,
#   'wind_speed': 25.610258263463113,
#   'primary_key': 26,
#   'pressure': 27.73016218864073}]
